# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanSingh0909/Data-engineer-learning-from-linkedin/blob/main/Interview_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

df = pd.read_json('/content/alerts_deidentified.json')
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of       AlertId    OrgId    UserId    DeviceId                 Timestamp  Bound  \
# 0   ALERT_001  ORG_001  USER_001  DEVICE_001 2026-04-09 23:18:30+00:00  UPPER
# 1   ALERT_002  ORG_001  USER_002  DEVICE_002 2026-04-09 23:20:00+00:00  LOWER
# 2   ALERT_003  ORG_001  USER_003  DEVICE_003 2026-04-09 23:11:00+00:00  UPPER
# 3   ALERT_004  ORG_001  USER_004  DEVICE_004 2026-04-09 23:16:13+00:00     NA
# 4   ALERT_005  ORG_001  USER_005  DEVICE_005 2026-04-09 22:37:30+00:00  UPPER
# 5   ALERT_006  ORG_001  USER_005  DEVICE_005 2026-04-09 22:23:30+00:00  UPPER
# 6   ALERT_007  ORG_001  USER_006  DEVICE_006 2026-04-09 21:56:00+00:00  UPPER
# 7   ALERT_008  ORG_001  USER_005  DEVICE_005 2026-04-09 21:41:00+00:00  UPPER
# 8   ALERT_009  ORG_001  USER_007  DEVICE_007 2026-04-09 21:29:00+00:00  UPPER
# 9   ALERT_010  ORG_001  USER_007  DEVICE_007 2026-04-09 20:58:30+00:00  UPPER
# 10  ALERT_011  ORG_001  USER_003  DEVICE_003 2026-04-09 21:00:06+00:00     NA
# ...

# %%
print(df['AlertId'].count())
# Out:
# 49

# %%
print(type())
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['Timestamp'].dtype
# Out:
# datetime64[ns, UTC]

# %%
y = df.columns.tolist()

# %%
x= df.columns

# %%
df['Timestamp'].max()
# Out:
# Timestamp('2026-04-09 23:20:00+0000', tz='UTC')

# %%
df['Timestamp'].min()
# Out:
# Timestamp('2026-04-01 19:12:00+0000', tz='UTC')

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %% [markdown]
# mask = (df['Timestamp'] >= '2026-04-02 16:47:30+00:00') & (df['Timestamp'] <= '2026-04-09 19:45:49+00:00')
#
# print(mask.to_string)

# %%
filtered_df = df[df['Timestamp'].between('2024-01-01', '2024-03-31')]
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [AlertId, OrgId, UserId, DeviceId, Timestamp, Bound, LowerThreshold, UpperThreshold, ParameterKey, ParameterValue, Source, Status, Stage, AlertCategory, StatusTimestamp, Color, Logs]
# Index: []
