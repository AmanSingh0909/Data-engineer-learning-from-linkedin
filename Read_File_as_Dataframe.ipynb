# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanSingh0909/Data-engineer-learning-from-linkedin/blob/main/Read_File_as_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/adf_sample_dataset_100_rows.csv')
print(df)
# Out:
#     employee_id   name       city department  salary   join_date    status
# 0             1   Amit      Delhi    Finance   91089  2022-11-01  Inactive
# 1             2  Kiran  Bangalore         HR   35608  2022-01-19  Inactive
# 2             3   Sara      Delhi  Marketing   63769  2023-04-27    Active
# 3             4  Rahul  Bangalore         HR  118444  2024-04-11    Active
# 4             5  Kiran     Mumbai    Finance   63995  2022-10-11  Inactive
# ..          ...    ...        ...        ...     ...         ...       ...
# 95           96   Ravi  Bangalore    Finance   34201  2023-09-24  Inactive
# 96           97   Amit      Delhi      Sales  100290  2024-04-07  Inactive
# 97           98  Pooja  Bangalore    Finance  112470  2023-01-13  Inactive
# 98           99   John      Delhi         IT  108658  2023-08-04    Active
# 99          100  Anita     Mumbai    Finance  107281  2023-08-18    Active
#
# [100 rows x 7 columns]

# %%
print(df.to_string())
# Out:
#     employee_id   name       city department  salary   join_date    status
# 0             1   Amit      Delhi    Finance   91089  2022-11-01  Inactive
# 1             2  Kiran  Bangalore         HR   35608  2022-01-19  Inactive
# 2             3   Sara      Delhi  Marketing   63769  2023-04-27    Active
# 3             4  Rahul  Bangalore         HR  118444  2024-04-11    Active
# 4             5  Kiran     Mumbai    Finance   63995  2022-10-11  Inactive
# 5             6   Sara    Chennai         IT   41107  2024-11-10    Active
# 6             7   Sara    Chennai         HR   34839  2022-11-28    Active
# 7             8   Ravi  Hyderabad    Finance   67633  2024-08-10    Active
# 8             9  Rahul      Delhi      Sales   68620  2024-10-25    Active
# 9            10  Pooja     Mumbai         IT   62885  2023-04-10  Inactive
# 10           11   Sara  Bangalore      Sales   40495  2022-01-21  Inactive
# ...

# %%
df1 = pd.read_json('/content/sample_data/anscombe.json')
print(df1)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...
